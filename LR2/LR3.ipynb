# %% [markdown]
# `Дисциплина: Методы и технологии машинного обучения`
# `Уровень подготовки: бакалавриат`
# `Направление подготовки: 01.03.02 Прикладная математика и информатика`
# `Семестр: осень 2022/2023`
#
#
#
#
# # Лабораторная работа №3: Линейные модели. Кросс-валидация.
#
# В практических примерах ниже показано:
#
# * как пользоваться инструментами предварительного анализа для поиска линейных взаимосвязей
# * как строить и интерпретировать линейные модели с логарифмами
# * как оценивать точность моделей с перекрёстной проверкой (LOOCV, проверка по блокам)
#
# *Модели*: множественная линейная регрессия
# *Данные*: `Boston_for_lab` (источник: <https://raw.githubusercontent.com/ania607/ML/main/data/Boston_for_lab.csv>)

# %% [markdown]
# # Указания к выполнению
#
#
# ## Загружаем пакеты

# %%
# загрузка пакетов: инструменты --------------------------------------------
#  работа с массивами
import numpy as np
#  фреймы данных
import pandas as pd
#  графики
import matplotlib as mpl
#  стили и шаблоны графиков на основе matplotlib
import seaborn as sns
# перекодировка категориальных переменных
from sklearn.preprocessing import LabelEncoder
#  тест Шапиро-Уилка на нормальность распределения
from scipy.stats import shapiro
#  для таймера
import time

# загрузка пакетов: модели -------------------------------------------------
#  линейные модели
import sklearn.linear_model as skl_lm
#  расчёт MSE
from sklearn.metrics import mean_squared_error
#  кросс-валидация
from sklearn.model_selection import train_test_split, LeaveOneOut 
from sklearn.model_selection import KFold, cross_val_score
#  полиномиальные модели
from sklearn.preprocessing import PolynomialFeatures

# %%
# константы
#  ядро для генератора случайных чисел
my_seed = 21
#  создаём псевдоним для короткого обращения к графикам
plt = mpl.pyplot
# настройка стиля и отображения графиков
#  примеры стилей и шаблонов графиков: 
#  http://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html
mpl.style.use('seaborn-whitegrid')
sns.set_palette("Set2")
# раскомментируйте следующую строку, чтобы посмотреть палитру
# sns.color_palette("Set2")

# %% [markdown]
# ## Загружаем данные
#
# Набор данных `Boston_for_lab` в формате .csv доступен для загрузки по адресу: <https://raw.githubusercontent.com/ania607/ML/main/data/Boston_for_lab.csv>.
# Загружаем данные во фрейм и кодируем категориальные переменные.

# %%
# читаем таблицу из файла .csv во фрейм
fileURL = 'https://raw.githubusercontent.com/ania607/ML/main/data/Boston_for_lab.csv'
DF_raw = pd.read_csv(fileURL)

# выясняем размерность фрейма
print('Число строк и столбцов в наборе данных:\n', DF_raw.shape)
# Out:
# Число строк и столбцов в наборе данных:
#  (506, 15)

# %%
# первые 5 строк фрейма
DF_raw.head(5)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv  tax_over_400
# 0  396.90   4.98  24.0             0
# 1  396.90   9.14  21.6             0
# 2  392.83   4.03  34.7             0
# 3  394.63   2.94  33.4             0
# 4  396.90   5.33  36.2             0

# %% [markdown]
# Здесь:
# * **crim**– уровень преступности на душу населения по району;
# * **zn**– доля земли под жилую застройку;
# * **indus**– доля акров, не связанных с розничной торговлей, на город;
# * **chas**– ;
# * **nox**– концентрация оксидов азота (частей на 10 миллионов);
# * **rm**– среднее количество комнат в доме;
# * **age**– возраст;
# * **dis**– средневзвешенное расстояние до пяти бостонских центров занятости;
# * **rad**– ;
# * **tax**– ;
# * **ptratio**– ;
# * **black**– ;
# * **lstat**– ;
# * **medv**– медианная стоимость домов, тыс. долл. США;
# * **tax_over_400**– полная ставка налога на имущество на $10000 больше 400 (0-нет;1-да).

# %%
# типы столбцов фрейма
DF_raw.dtypes
# Out:
# crim            float64
# zn              float64
# indus           float64
# chas              int64
# nox             float64
# rm              float64
# age             float64
# dis             float64
# rad               int64
# tax               int64
# ptratio         float64
# black           float64
# lstat           float64
# medv            float64
# tax_over_400      int64
# dtype: object

# %% [markdown]
# Проверим, нет ли в таблице пропусков.

# %%
# считаем пропуски в каждом столбце
DF_raw.isna().sum()
# Out:
# crim            0
# zn              0
# indus           0
# chas            0
# nox             0
# rm              0
# age             0
# dis             0
# rad             0
# tax             0
# ptratio         0
# black           0
# lstat           0
# medv            0
# tax_over_400    0
# dtype: int64

# %% [markdown]
# Пропусков не обнаружено.

# %%
# находим уникальные medv
DF_raw['rad'].unique()
# Out:
# array([ 1,  2,  3,  5,  4,  8,  6,  7, 24], dtype=int64)

# %%
#  добавляем фиктивные на регион: число фиктивных = число уникальных - 1
df_dummy = pd.get_dummies(DF_raw[['rad']], drop_first=True)
df_dummy.head(5)
# Out:
#    rad
# 0    1
# 1    2
# 2    2
# 3    3
# 4    3

# %%
# объединяем с исходным фреймом
DF_all = pd.concat([DF_raw.reset_index(drop=True), df_dummy], axis=1)

# сколько теперь столбцов
DF_all.shape
# Out:
# (506, 16)

# %%
# смотрим первые 8 столбцов
DF_all.iloc[:, :8].head(5)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622

# %%
# смотрим последние 8 столбцов
DF_all.iloc[:, 8:].head(5)
# Out:
#    rad  tax  ptratio   black  lstat  medv  tax_over_400  rad
# 0    1  296     15.3  396.90   4.98  24.0             0    1
# 1    2  242     17.8  396.90   9.14  21.6             0    2
# 2    2  242     17.8  392.83   4.03  34.7             0    2
# 3    3  222     18.7  394.63   2.94  33.4             0    3
# 4    3  222     18.7  396.90   5.33  36.2             0    3

# %%
# оставляем в наборе данных только то, что нужно
DF_all = DF_all[['medv', 'zn', 'indus', 'tax_over_400']]

# перекодируем регион в числовой фактор, 
#  чтобы использовать на графиках
class_le = LabelEncoder()
DF_all['medv'] = class_le.fit_transform(DF_all.medv.values)

DF_all.columns
# Out:
# Index(['medv', 'zn', 'indus', 'tax_over_400'], dtype='object')

# %%
DF_all.dtypes
# Out:
# medv              int64
# zn              float64
# indus           float64
# tax_over_400      int64
# dtype: object

# %%
# удаляем фрейм-исходник
del DF_raw

# %% [markdown]
# Прежде чем переходить к анализу данных, разделим фрейм на две части: одна (80%) станет основой для обучения моделей, на вторую (20%) мы сделаем прогноз по лучшей модели.

# %%
# данные для построения моделей
DF = DF_all.sample(frac = 0.8, random_state = my_seed)

# данные для прогнозов
DF_predict = DF_all.drop(DF.index)

# %% [markdown]
# ## Предварительный анализ данных
#
# ### Считаем описательные статистики
#
# Рассчитаем описательные статистики для непрерывных переменных. Из таблицы ниже можно видеть, что переменная `medv`, которая является зависимой переменной модели, сильно отличается по масштабу от всех остальных.    Также заметим, что из всех объясняющих только переменная `tax_over_400` принимает нулевые значения. Остальные показатели положительны.

# %%
# описательные статистики для непрерывных переменных
DF[['medv', 'zn', 'indus', 'tax_over_400']].describe()
# Out:
#              medv          zn       indus  tax_over_400
# count  405.000000  405.000000  405.000000    405.000000
# mean   109.385185   11.455556   11.242691      0.412346
# std     58.206314   23.904523    6.830773      0.492866
# min      0.000000    0.000000    0.460000      0.000000
# 25%     65.000000    0.000000    5.190000      0.000000
# 50%    110.000000    0.000000    9.690000      0.000000
# 75%    145.000000   12.500000   18.100000      1.000000
# max    228.000000  100.000000   27.740000      1.000000

# %% [markdown]
# ### Строим графики
#
# Посмотрим на графики взаимного разброса непрерывных переменных.

# %%
# матричный график разброса с линиями регрессии
sns.pairplot(DF[['medv', 'zn', 'indus', 'tax_over_400']])
plt.show()

# %%
# матричный график разброса с цветом по медианной стоимости домов
sns.pairplot(DF[['medv', 'zn', 'indus', 'tax_over_400']],
            hue='medv')

plt.show()

# %% [markdown]
# Теперь покажем цветом на графиках отношение домов к полной ставке налога на имущество на $10000 больше 400.

# %%
# матричный график разброса с цветом по tax_over_400
sns.pairplot(DF[['medv', 'zn', 'indus', 'tax_over_400']],
            hue='tax_over_400')

plt.show()

# %% [markdown]
# Покажем с помощью цвета на графиках долю земли под жилую застройку.

# %%
# матричный график разброса с цветом по zn
sns.pairplot(DF[['medv', 'zn', 'indus', 'tax_over_400']], hue='zn')
plt.show()

# %% [markdown]
# Нарисуем график отдельно по `region_southeast`.

# %%
# матричный график разброса с цветом по indus
sns.pairplot(DF[['medv', 'zn', 'indus', 'tax_over_400']], hue='indus')
plt.show()

# %% [markdown]
# Посмотрим на корреляционные матрицы непрерывных переменных фрейма.

# %%
# корреляционная матрица по всем наблюдениям
corr_mat = DF[['medv', 'zn', 'indus', 'tax_over_400']].corr()
corr_mat.style.background_gradient(cmap='coolwarm').set_precision(2)
#corr_mat
# Out:
# <style  type="text/css" >
# #T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row0_col0,#T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row1_col1,#T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row2_col2,#T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row3_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row0_col1{
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }#T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row0_col2,#T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row0_col3,#T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row2_col0,#T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row2_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row1_col0{
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }#T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row1_col2{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row1_col3{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row2_col3{
#             background-color:  #de614d;
#             color:  #000000;
#         }#T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row3_col0{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row3_col1{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row3_col2{
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }</style><table id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >medv</th>        <th class="col_heading level0 col1" >zn</th>        <th class="col_heading level0 col2" >indus</th>        <th class="col_heading level0 col3" >tax_over_400</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834level0_row0" class="row_heading level0 row0" >medv</th>
#                         <td id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row0_col1" class="data row0 col1" >0.40</td>
#                         <td id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row0_col2" class="data row0 col2" >-0.57</td>
#                         <td id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row0_col3" class="data row0 col3" >-0.50</td>
#             </tr>
#             <tr>
#                         <th id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834level0_row1" class="row_heading level0 row1" >zn</th>
#                         <td id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row1_col0" class="data row1 col0" >0.40</td>
#                         <td id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row1_col2" class="data row1 col2" >-0.54</td>
#                         <td id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row1_col3" class="data row1 col3" >-0.33</td>
#             </tr>
#             <tr>
#                         <th id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834level0_row2" class="row_heading level0 row2" >indus</th>
#                         <td id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row2_col0" class="data row2 col0" >-0.57</td>
#                         <td id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row2_col1" class="data row2 col1" >-0.54</td>
#                         <td id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row2_col3" class="data row2 col3" >0.81</td>
#             </tr>
#             <tr>
#                         <th id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834level0_row3" class="row_heading level0 row3" >tax_over_400</th>
#                         <td id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row3_col0" class="data row3 col0" >-0.50</td>
#                         <td id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row3_col1" class="data row3 col1" >-0.33</td>
#                         <td id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row3_col2" class="data row3 col2" >0.81</td>
#                         <td id="T_ff2fcf00_50b5_11ed_bef2_e4aaea5c9834row3_col3" class="data row3 col3" >1.00</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Посчитаем корреляционные матрицы для полной ставки налога на имущество на $10000 превышающей и не превышающей 400.

# %%
# корреляционная матрица по классу полная ставка налога на имущество на $10000 больше 400
corr_mat = DF.loc[DF['tax_over_400'] == 1][['medv', 'zn', 'indus']].corr()
#corr_mat.style.background_gradient(cmap='coolwarm').set_precision(2)
corr_mat.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row0_col0,#T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row1_col1,#T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row2_col2{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row0_col1{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row0_col2{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row1_col0{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row1_col2,#T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row2_col0,#T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row2_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >medv</th>        <th class="col_heading level0 col1" >zn</th>        <th class="col_heading level0 col2" >indus</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834level0_row0" class="row_heading level0 row0" >medv</th>
#                         <td id="T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row0_col1" class="data row0 col1" >0.23</td>
#                         <td id="T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row0_col2" class="data row0 col2" >-0.20</td>
#             </tr>
#             <tr>
#                         <th id="T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834level0_row1" class="row_heading level0 row1" >zn</th>
#                         <td id="T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row1_col0" class="data row1 col0" >0.23</td>
#                         <td id="T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row1_col2" class="data row1 col2" >-0.59</td>
#             </tr>
#             <tr>
#                         <th id="T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834level0_row2" class="row_heading level0 row2" >indus</th>
#                         <td id="T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row2_col0" class="data row2 col0" >-0.20</td>
#                         <td id="T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row2_col1" class="data row2 col1" >-0.59</td>
#                         <td id="T_ff3378a8_50b5_11ed_8bb8_e4aaea5c9834row2_col2" class="data row2 col2" >1.00</td>
#             </tr>
#     </tbody></table>

# %%
# корреляционная матрица по классу полная ставка налога на имущество на $10000 400 и меньше
corr_mat = DF.loc[DF['tax_over_400'] == 0][['medv', 'zn', 'indus']].corr()
#corr_mat.style.background_gradient(cmap='coolwarm').set_precision(2)
corr_mat.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row0_col0,#T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row1_col1,#T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row2_col2{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row0_col1{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row0_col2{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row1_col0{
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }#T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row1_col2,#T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row2_col0,#T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row2_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_fff88d1c_50b5_11ed_8710_e4aaea5c9834" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >medv</th>        <th class="col_heading level0 col1" >zn</th>        <th class="col_heading level0 col2" >indus</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fff88d1c_50b5_11ed_8710_e4aaea5c9834level0_row0" class="row_heading level0 row0" >medv</th>
#                         <td id="T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row0_col1" class="data row0 col1" >0.34</td>
#                         <td id="T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row0_col2" class="data row0 col2" >-0.43</td>
#             </tr>
#             <tr>
#                         <th id="T_fff88d1c_50b5_11ed_8710_e4aaea5c9834level0_row1" class="row_heading level0 row1" >zn</th>
#                         <td id="T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row1_col0" class="data row1 col0" >0.34</td>
#                         <td id="T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row1_col2" class="data row1 col2" >-0.50</td>
#             </tr>
#             <tr>
#                         <th id="T_fff88d1c_50b5_11ed_8710_e4aaea5c9834level0_row2" class="row_heading level0 row2" >indus</th>
#                         <td id="T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row2_col0" class="data row2 col0" >-0.43</td>
#                         <td id="T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row2_col1" class="data row2 col1" >-0.50</td>
#                         <td id="T_fff88d1c_50b5_11ed_8710_e4aaea5c9834row2_col2" class="data row2 col2" >1.00</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Логарифмируем зависимую переменную
#
# Важным допущением линейной регрессии является нормальность зависимой переменной. Чтобы добиться нормального распределения, используют логарифмирование либо преобразование Бокса-Кокса. В этой лабораторной остановимся на логарифмировании.

# %%
# логарифмируем зависимую переменную
DF['log_medv'] = np.log(DF['medv'])

# описательные статистики для непрерывных показателей
DF[['medv', 'log_medv', 'zn', 'indus', 'tax_over_400']].describe()
# Out:
# c:\python310\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#              medv    log_medv          zn       indus  tax_over_400
# count  405.000000  405.000000  405.000000  405.000000    405.000000
# mean   109.385185        -inf   11.455556   11.242691      0.412346
# std     58.206314         NaN   23.904523    6.830773      0.492866
# min      0.000000        -inf    0.000000    0.460000      0.000000
# 25%     65.000000    4.174387    0.000000    5.190000      0.000000
# 50%    110.000000    4.700480    0.000000    9.690000      0.000000
# 75%    145.000000    4.976734   12.500000   18.100000      1.000000
# max    228.000000    5.429346  100.000000   27.740000      1.000000

# %% [markdown]
# Проведём формальные тесты на нормальность.

# %%
# тестируем на нормальность
for col in ['medv', 'log_medv']:
    stat, p = shapiro(DF[col])
    print(col, 'Statistics=%.2f, p=%.4f' % (stat, p))
    # интерпретация
    alpha = 0.05
    if p > alpha:
        print('Распределение нормально (H0 не отклоняется)\n')
    else:
        print('Распределение не нормально (H0 отклоняется)\n')
# Out:
# medv Statistics=0.98, p=0.0000
# Распределение не нормально (H0 отклоняется)
#
# log_medv Statistics=nan, p=1.0000
# Распределение нормально (H0 не отклоняется)

# %% [markdown]
# Логарифмирование меняет взаимосвязи между переменными.

# %%
# матричный график разброса с цветом по tax_over_400
sns.pairplot(DF[['log_medv', 'zn', 'indus', 'tax_over_400']], hue='tax_over_400')
plt.show()

# %%
# корреляционная матрица по классу полная ставка налога на имущество на $10000 400 и меньше
corr_mat = DF.loc[DF['tax_over_400'] == 0][['log_medv', 'zn', 'indus']].corr()
#corr_mat.style.background_gradient(cmap='coolwarm').set_precision(2)
corr_mat.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row0_col0,#T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row1_col1,#T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row2_col2{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row0_col1{
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }#T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row0_col2{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row1_col0{
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }#T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row1_col2,#T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row2_col0,#T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row2_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >log_medv</th>        <th class="col_heading level0 col1" >zn</th>        <th class="col_heading level0 col2" >indus</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834level0_row0" class="row_heading level0 row0" >log_medv</th>
#                         <td id="T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row0_col1" class="data row0 col1" >0.32</td>
#                         <td id="T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row0_col2" class="data row0 col2" >-0.39</td>
#             </tr>
#             <tr>
#                         <th id="T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834level0_row1" class="row_heading level0 row1" >zn</th>
#                         <td id="T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row1_col0" class="data row1 col0" >0.32</td>
#                         <td id="T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row1_col2" class="data row1 col2" >-0.50</td>
#             </tr>
#             <tr>
#                         <th id="T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834level0_row2" class="row_heading level0 row2" >indus</th>
#                         <td id="T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row2_col0" class="data row2 col0" >-0.39</td>
#                         <td id="T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row2_col1" class="data row2 col1" >-0.50</td>
#                         <td id="T_03722a5a_50b6_11ed_b9fa_e4aaea5c9834row2_col2" class="data row2 col2" >1.00</td>
#             </tr>
#     </tbody></table>

# %%
# корреляционная матрица по классу полная ставка налога на имущество на $10000 больше 400
corr_mat = DF.loc[DF['tax_over_400'] == 1][['log_medv', 'zn', 'indus']].corr()
#corr_mat.style.background_gradient(cmap='coolwarm').set_precision(2)
corr_mat.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row0_col0,#T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row1_col1,#T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row2_col2{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row0_col1{
#             background-color:  #d6dce4;
#             color:  #000000;
#         }#T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row0_col2{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row1_col0{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row1_col2,#T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row2_col0,#T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row2_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >log_medv</th>        <th class="col_heading level0 col1" >zn</th>        <th class="col_heading level0 col2" >indus</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834level0_row0" class="row_heading level0 row0" >log_medv</th>
#                         <td id="T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row0_col1" class="data row0 col1" >0.16</td>
#                         <td id="T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row0_col2" class="data row0 col2" >-0.20</td>
#             </tr>
#             <tr>
#                         <th id="T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834level0_row1" class="row_heading level0 row1" >zn</th>
#                         <td id="T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row1_col0" class="data row1 col0" >0.16</td>
#                         <td id="T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row1_col2" class="data row1 col2" >-0.59</td>
#             </tr>
#             <tr>
#                         <th id="T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834level0_row2" class="row_heading level0 row2" >indus</th>
#                         <td id="T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row2_col0" class="data row2 col0" >-0.20</td>
#                         <td id="T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row2_col1" class="data row2 col1" >-0.59</td>
#                         <td id="T_03d2e7ee_50b6_11ed_a4d7_e4aaea5c9834row2_col2" class="data row2 col2" >1.00</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Строим модели регрессии
#
# ### Спецификация моделей
# По итогам предварительного анализа данных можно предложить следующие спецификации линейных регрессионных моделей:
#
# 1. `fit_lm_1`: $\hat{medv} = \hat{\beta_0} + \hat{\beta_1} \cdot tax_over_400 + \hat{\beta_2} \cdot zn + \hat{\beta_3} \cdot indus$
# 1. `fit_lm_2`: $\hat{medv} = \hat{\beta_0} + \hat{\beta_1} \cdot tax_over_400 + \hat{\beta_2} \cdot zn \cdot tax_over_400 + \hat{\beta_3} \cdot indus$
# 1. `fit_lm_3`: $\hat{medv} = \hat{\beta_0} + \hat{\beta_1} \cdot tax_over_400 + \hat{\beta_2} \cdot indus \cdot tax_over_400 + \hat{\beta_3} \cdot zn$
# 1. `fit_lm_4`: $\hat{medv} = \hat{\beta_0} + \hat{\beta_1} \cdot tax_over_400 + \hat{\beta_2} \cdot indus \cdot tax_over_400 + \hat{\beta_3} \cdot zn \cdot tax_over_400$
#
# 1. `fit_lm_1_log`: то же, что `fit_lm_1`, но для зависимой $\hat{log\_medv}$
# 1. `fit_lm_2_log`: то же, что `fit_lm_2`, но для зависимой $\hat{log\_medv}$
# 1. `fit_lm_3_log`: то же, что `fit_lm_3`, но для зависимой $\hat{log\_medv}$
# 1. `fit_lm_4_log`: то же, что `fit_lm_4`, но для зависимой $\hat{log\_medv}$
#
# Кроме того, добавим в сравнение модели зависимости `medv` и `log_medv` от всех объясняющих переменных: `fit_lm_0` и `fit_lm_0_log` соответственно.
#
#
# ### Обучение и интерпретация
#
# Создаём матрицы значений объясняющих переменных ( $X$ ) и вектора значений зависимой ( $y$ ) для всех моделей.

# %%
# данные для моделей 1, 5
df1 = DF[['medv', 'zn', 'indus', 'tax_over_400']]

# данные для моделей 2, 6
df2 = DF[['medv', 'zn', 'indus', 'tax_over_400']]
df2.loc[:, 'zn_tax_over_400'] = df2.loc[:, 'zn'] * df2.loc[:, 'tax_over_400']
df2 = df2.drop(['zn'], axis=1)

# данные для моделей 3, 7
df3 = DF[['medv', 'zn', 'indus', 'tax_over_400']]
df3.loc[:, 'indus_tax_over_400'] = df3.loc[:, 'indus'] * df3.loc[:, 'tax_over_400']
df3 = df3.drop(['indus'], axis=1)

# данные для моделей 4, 8
df4 = DF[['medv', 'zn', 'indus', 'tax_over_400']]
df4.loc[:, 'zn_tax_over_400'] = df4.loc[:, 'zn'] * df4.loc[:, 'tax_over_400']
df4.loc[:, 'indus_tax_over_400'] = df4.loc[:, 'indus'] * df4.loc[:, 'tax_over_400']
df4 = df4.drop(['zn', 'indus'], axis=1)

# данные для моделей 9, 10
df0 = DF.drop(['log_medv'], axis=1)

# %%
# проверка результатов
df4.head()
# Out:
#      medv  tax_over_400  zn_tax_over_400  indus_tax_over_400
# 455    44             1              0.0               18.10
# 142    38             1              0.0               19.58
# 311   118             0              0.0                0.00
# 232   214             0              0.0                0.00
# 290   163             0              0.0                0.00

# %% [markdown]
# Построим модели от всех объясняющих переменных на всех наблюдениях `DF`, чтобы проинтерпретировать параметры. В модели для зависимой переменной `medv` интерпретация стандартная:
#
# 1. Константа – базовый уровень зависимой переменной, когда все объясняющие равны 0.
# 2. Коэффициент при объясняющей переменной $X$ показывает, на сколько своих единиц измерения изменится $Y$, если $X$ увеличится на одну свою единицу измерения.

# %%
lm = skl_lm.LinearRegression()

# модель со всеми объясняющими, y
X = df0.drop(['medv'], axis=1)
y = df0.medv.values.reshape(-1, 1)
fit_lm_0 = lm.fit(X, y)
print('модель fit_lm_0:\n', 
      'константа ', np.around(fit_lm_0.intercept_, 3),
      '\n объясняющие ', list(X.columns.values),
      '\n коэффициенты ', np.around(fit_lm_0.coef_, 3))
# Out:
# модель fit_lm_0:
#  константа  [147.473]
#  объясняющие  ['zn', 'indus', 'tax_over_400']
#  коэффициенты  [[  0.362  -3.038 -19.59 ]]

# %%
# оценим MSE на обучающей
#  прогнозы
y_pred = fit_lm_0.predict(X)
MSE = sum((y - y_pred.reshape(-1, 1))**2) / len(y)
np.sqrt(MSE)
# Out:
# array([46.98699784])

# %% [markdown]
# С интерпретацией модели на логарифме $Y$ дела обстоят сложнее:
# 1. Константу сначала надо экспоненциировать, далее интерпретировать как для обычной модели регрессии.
# 1. Коэффициент при $X$ нужно экспоненциировать, затем вычесть из получившегося числа 1, затем умножить на 100. Результат показывает, на сколько процентов изменится (увеличится, если коэффициент положительный, и уменьшится, если отрицательный) зависимая переменная, если $X$ увеличится на одну свою единицу измерения.

# %%
# модель со всеми объясняющими, y_log
from numpy import inf
X = df0.drop(['medv'], axis=1)
y = np.log(df0.medv).values.reshape(-1, 1)
y[y == -inf] = 0.0000001

fit_lm_0_log = lm.fit(X, y)
print('модель fit_lm_0_log:\n', 
      'константа ', np.around(fit_lm_0_log.intercept_, 3),
      '\n объясняющие ', list(X.columns.values),
      '\n коэффициенты ', np.around(fit_lm_0_log.coef_, 3))
# Out:
# модель fit_lm_0_log:
#  константа  [5.021]
#  объясняющие  ['zn', 'indus', 'tax_over_400']
#  коэффициенты  [[ 0.003 -0.036 -0.462]]
# c:\python310\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# пересчёт коэффициентов для их интерпретации
np.around((np.exp(fit_lm_0_log.coef_) - 1) * 100, 1)
# Out:
# array([[  0.3,  -3.6, -37. ]])

# %%
# оценим MSE на обучающей
#  прогнозы
y_pred = fit_lm_0_log.predict(X)
MSE_log = sum((np.exp(y) - np.exp(y_pred).reshape(-1, 1))**2) / len(y)
np.sqrt(MSE_log)
# Out:
# array([49.3538367])

# %%
print('MSE_train модели для medv меньше MSE_train',
     'модели для log(medv) в ', np.around(MSE_log / MSE, 1), 'раз')
# Out:
# MSE_train модели для medv меньше MSE_train модели для log(medv) в  [1.1] раз

# %% [markdown]
# ### Оценка точности
#
# #### LOOCV
#
# Сделаем перекрёстную проверку точности моделей по одному наблюдению.

# %%
# LeaveOneOut CV
loo = LeaveOneOut()


# модели для y
scores = list()
# таймер
tic = time.perf_counter()
for df in [df0, df1, df2, df3, df4] :
    loo.get_n_splits(df)
    X = df.drop(['medv'], axis=1)
    y = df.medv
    score = cross_val_score(lm, X, y, cv=loo, scoring='neg_mean_squared_error').mean()
    scores.append(score)

# таймер
toc = time.perf_counter()
print(f"Расчёты методом LOOCV заняли {toc - tic:0.2f} секунд")
# Out:
# Расчёты методом LOOCV заняли 8.47 секунд

# %%
df0.shape
# Out:
# (405, 4)

# %%
# модели для y_log
scores_log = list()
# таймер
tic = time.perf_counter()
for df in [df0, df1, df2, df3, df4] :
    loo.get_n_splits(df)
    X = df.drop(['medv'], axis=1)
    y = np.log(df.medv)
    y[y == -inf] = 0.0000001
    score = cross_val_score(lm, X, y, cv=loo, n_jobs=1,
                            scoring='neg_mean_squared_error').mean()
    scores_log.append(score)

# таймер
toc = time.perf_counter()
print(f"Расчёты методом LOOCV заняли {toc - tic:0.2f} секунд")
# Out:
# c:\python310\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\python310\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\python310\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\python310\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\python310\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Расчёты методом LOOCV заняли 8.75 секунд

# %% [markdown]
# Сравним ошибки для моделей на исходных значениях `medv` с ошибками моделей на логарифме.

# %%
scores
# Out:
# [-2245.2780251723516,
#  -2245.2780251723516,
#  -2295.0917751138,
#  -2340.233609494756,
#  -2482.3234890364956]

# %%
[np.around(-x, 2) for x in scores]
# Out:
# [2245.28, 2245.28, 2295.09, 2340.23, 2482.32]

# %%
[np.around(-x, 3) for x in scores_log]
# Out:
# [0.556, 0.556, 0.556, 0.562, 0.572]

# %% [markdown]
# Определим самые точные модели отдельно на `medv` и на `log_medv`.

# %%
# самая точная на medv
fits = ['fit_lm_0', 'fit_lm_1', 'fit_lm_2', 'fit_lm_3', 'fit_lm_4']
print('Наименьшая ошибка на тестовой с LOOCV у модели',
      fits[scores.index(max(scores))], 
      ':\nMSE_loocv =', np.around(-max(scores), 0))
# Out:
# Наименьшая ошибка на тестовой с LOOCV у модели fit_lm_0 :
# MSE_loocv = 2245.0

# %%
# самая точная на log(medv)
fits = ['fit_lm_0_log', 'fit_lm_1_log', 'fit_lm_2_log',
    'fit_lm_3_log', 'fit_lm_4_log']
print('Наименьшая ошибка на тестовой с LOOCV у модели',
    fits[scores_log.index(max(scores_log))],
    ':\nMSE_loocv =', np.around(-max(scores_log), 3))
# Out:
# Наименьшая ошибка на тестовой с LOOCV у модели fit_lm_0_log :
# MSE_loocv = 0.556

# %% [markdown]
# Самой точной среди моделей для `medv` оказалась `fit_lm_3`, а среди моделей для `medv_log` – `fit_lm_0_log`. Оценим точность прогноза по этим моделям на отложенные наблюдения.

# %%
# прогноз по fit_lm_3
#  модель на всех обучающих наблюдениях
X = df3.drop(['medv'], axis=1)
y = df3.medv.values.reshape(-1, 1)
fit_lm_3 = lm.fit(X, y)

#  значения y на отложенных наблюдениях
y = DF_predict[['medv']].values.reshape(-1, 1)
#  матрица объясняющих на отложенных наблюдениях
X = DF_predict[['tax_over_400', 'zn', 'indus', ]]
X.loc[:, 'indus_tax_over_400'] = X.loc[:, 'indus'] * X.loc[:, 'tax_over_400']
X = X.drop(['indus'], axis=1)
#  прогнозы
y_pred = fit_lm_3.predict(X)

# ошибка
MSE = sum((y - y_pred.reshape(-1, 1))**2) / len(y)
print('MSE модели fit_lm_3 на отложенных наблюдениях = %.2f' % MSE)
# Out:
# MSE модели fit_lm_3 на отложенных наблюдениях = 266685.50
# c:\python310\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)

# %%
# прогноз по fit_lm_log_0
# модель
X = df0.drop(['medv'], axis=1)
y = np.log(df0.medv).values.reshape(-1, 1)
y[y == -inf] = 0 
fit_lm_0_log = lm.fit(X, y)

#  значения y на отложенных наблюдениях
y = np.log(DF_predict[['medv']].values.reshape(-1, 1))
#  матрица объясняющих на отложенных наблюдениях
X = DF_predict.drop(['medv'], axis=1)

#  прогнозы
y_pred = fit_lm_0_log.predict(X)

# ошибка
MSE_log = sum((np.exp(y) - np.exp(y_pred).reshape(-1, 1))**2) / len(y)
print('MSE модели fit_lm_0_log на отложенных наблюдениях = %.2f' % MSE_log)
# Out:
# MSE модели fit_lm_0_log на отложенных наблюдениях = 2444.48
# c:\python310\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
np.sqrt(MSE_log) / np.mean(DF_predict[['medv']]) * 100
# Out:
# medv    42.633035
# dtype: float64

# %%
np.sqrt(MSE) / np.mean(DF_predict[['medv']]) * 100
# Out:
# medv    445.300246
# dtype: float64

# %% [markdown]
# Очевидно, на выборке для прогноза точнее модель `fit_lm_3`:
# $\hat{medv} = \hat{\beta_0} + \hat{\beta_1} \cdot tax_over_400 + \hat{\beta_2} \cdot indus \cdot tax_over_400 + \hat{\beta_3} \cdot zn$

# %%
X = df3.drop(['medv'], axis=1)
y = df3.medv.values.reshape(-1, 1)
fit_lm_3 = lm.fit(X, y)

print('модель fit_lm_3:\n', 
      'константа ', np.around(fit_lm_3.intercept_, 3),
      '\n объясняющие ', list(df3.drop(['medv'], axis=1).columns.values),
      '\n коэффициенты ', np.around(fit_lm_3.coef_, 3))
# Out:
# модель fit_lm_3:
#  константа  [123.341]
#  объясняющие  ['zn', 'tax_over_400', 'indus_tax_over_400']
#  коэффициенты  [[  0.586 -21.103  -1.626]]

# %% [markdown]
# # Источники
#
# 1. *James G., Witten D., Hastie T. and Tibshirani R.*  An Introduction to Statistical Learning with Applications in R. URL: [http://www-bcf.usc.edu/~gareth/ISL/ISLR%20First%20Printing.pdf](https://drive.google.com/file/d/15PdWDMf9hkfP8mrCzql_cNiX2eckLDRw/view?usp=sharing)
# 1. Рашка С. Python и машинное обучение: крайне необходимое пособие по новейшей предсказательной аналитике, обязательное для более глубокого понимания методологии машинного обучения / пер. с англ. А.В. Логунова. – М.: ДМК Пресс, 2017. – 418 с.: ил.
# 1. Interpreting Log Transformations in a Linear Model / virginia.edu. URL: <https://data.library.virginia.edu/interpreting-log-transformations-in-a-linear-model/>
# 1. Python Timer Functions: Three Ways to Monitor Your Code / realpython.com. URL: <https://realpython.com/python-timer/>
